# %% [markdown]
# Seaborn es una librería construida sobre Matplotlib, por lo que hereda todas las bondades de la misma. Está integrada para estructuras de Pandas por lo que está optimizada para funcionar con DataFrames.

# %% [markdown]
# Algunas de sus ventajas principales
#
# * Tiene una gran velocidad
# * Facilidad para escribir código
# * Altamente customizable entre gráficas y visualizaciones

# %%
# Estructura básica

'''sns.'Tipo de Gráfica'(
		 data='Dataset',
		 x='Data en el eje x',
		 y='Data en el eje y',
		 hue='Variable de agrupamiento')'''
# Out:
# "sns.'Tipo de Gráfica'(\n\t\t data='Dataset',\n\t\t x='Data en el eje x',\n\t\t y='Data en el eje y',\n\t\t hue='Variable de agrupamiento')"

# %% [markdown]
# Seaborn ofrece ciertas características principales para problemas específicos de visualización de datos:
#
# * Diagramas o gráficas relacionales
# * Distribución de datos
# * Gráficar variables categóricas

# %% [markdown]
# La forma mas común de utilizar la librería es:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Set
#
# Set es un método de Seaborn que permite configurar el estilo, fuente y color de las gráficas.

# %% [markdown]
# ## Crear gráficas de Barplot

# %%
sns.barplot(x=['A','B','C'], y=[1,3,2])
plt.show()

# %% [markdown]
# ### Configurar fuentes y estilos

# %%
sns.set(style='dark', palette='dark', font="Verdana", font_scale=1)
sns.barplot(x=['A','B','C'], y=[1,3,2])
plt.show()

# %% [markdown]
# > - Este parámetro afecta a todas las gráficas que creamos, incluidas las que no usan Seaborn.
# > - Podemos resetear los valores utilizando el método `reset_orig`.
# > - Este parámetro es un atajo de `set_theme`, que es el recomendado según la documentación

# %% [markdown]
# # Parámetros más usados con Seaborn

# %% [markdown]
# Seaborn cuenta con un conjunto de dataFrame que trae por defecto. Usaremos el dataset **tips** para mostrar los diferentes parámetros con el que podemos configurar una gráfica

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Gráfico de frecuencia para el total de la cuenta

# %%
'''
Estructura a seguir 

sns.tipo_de_gráfica(data = dataframe, x = 'valores')

'''


sns.displot(data= tips, x= 'total_bill');

# %% [markdown]
# > Podemos utilizar `;` para evitar `plt.show()`

# %% [markdown]
# Posee la capacidad de generar el gráfico que mejor se adapte a lo que buscamos representar

# %%
# agregamos la entrada y

sns.displot(data= tips, x= 'total_bill', y= 'tip');

# %% [markdown]
# Podemos agregar un agrupamiento utilizando `hue`

# %%
sns.displot(data= tips, x= 'total_bill', y= 'tip', hue = 'sex');

# %% [markdown]
# Utilizamos `kind` para cambiar el tipo de gráfica

# %%
sns.displot(data= tips, x= 'total_bill', hue = 'sex', kind = 'kde');

# %% [markdown]
# Ademas podemos quitar la legenda, cambiar la paleta de colores y su transparencia

# %%
sns.displot(data= tips, x= 'total_bill', hue = 'sex', kind = 'kde', legend= False, palette='dark', alpha = .5);

# %% [markdown]
# # Distribuciones
#
# Seaborn ofrece algunas gráficas u opciones que te permiten trabajar con distribuciones orientadas a tipos de datos numéricos.

# %% [markdown]
# ## Uso de `.kde` y `.displot` para gráficar distribuciones

# %% [markdown]
# Gráfico para distribuciones y que se acumulen `cumulative`

# %%
sns.histplot(data = tips, x= 'tip', bins = 15, cumulative=True);

# %% [markdown]
# Como muestra en el eje y `stat`, presentar los datos `multiple`

# %%
sns.histplot(data = tips, x= 'tip', bins = 15, hue= 'sex', stat = 'density', multiple= 'dodge');

# %% [markdown]
# ### Uso de `.kde`
#
# Gráfica de densidad

# %%
sns.kdeplot(data=tips, x='tip', hue='sex');

# %% [markdown]
# Con acumulación

# %%
sns.kdeplot(data=tips, x='tip', hue='sex', cumulative=True);

# %% [markdown]
# Agregando el area bajo la curva

# %%
sns.kdeplot(data=tips, x='tip', hue='sex', fill=True);

# %% [markdown]
# ### Uso de `.displot`

# %% [markdown]
# Gráfica de distribución
#
# Haciendo solo uso de un tipo de grafico, pero utilizando `kind` podemos cambiar completamente como se presentan los datos, se podría considerar `displot` como una gráfica general

# %%
sns.displot(data = tips, x = 'tip', hue = 'sex',kind= 'hist', multiple= 'stack');

# %% [markdown]
# # Categóricos

# %% [markdown]
# ## Tipos de datos categóricos para graficar en Seaborn

# %% [markdown]
# ### Gráfica de cantidad

# %%
sns.countplot(data = tips, x= 'day', hue='sex');

# %% [markdown]
# ### Diagrama de puntos

# %%
sns.swarmplot(data= tips, x= 'day', y = 'total_bill', hue= 'sex', dodge=True);

# %% [markdown]
# ### Diagrama de caja

# %%
sns.boxplot(data= tips, x= 'day', y = 'total_bill', hue= 'sex', dodge=True);

# %% [markdown]
# ### Violín
#
# parecido a Boxplot, pero no muestra los cuartiles, sino como se concentran los datos con comparación split

# %%
sns.violinplot(data= tips, x= 'day', y = 'total_bill', hue= 'sex', split=True);

# %% [markdown]
# ### Catplot
#
# Puede interpretarse como una grafica general para datos categóricos
#
# > con `kind` podemos cambiar el tipo de gráfico y se puede agregar otra variable `col`

# %%
sns.catplot(data= tips, x= 'day', y = 'total_bill', hue= 'sex', dodge=True, kind= 'box', col= 'time');

# %% [markdown]
# > Podemos combinar varios gráficos

# %%
sns.boxplot(data= tips, x= 'day', y = 'total_bill', hue= 'sex', dodge=True);
sns.swarmplot(data= tips, x= 'day', y = 'total_bill', hue= 'sex', dodge=True, palette='dark:0', marker= '<');

# %% [markdown]
# # Relación

# %% [markdown]
# ## Tipos de gráficos de relación en Seaborn

# %% [markdown]
# ### Scatter

# %%
sns.scatterplot(data= tips, x= 'total_bill', y = 'tip', hue= 'day');

# %% [markdown]
# Cambiar el estilo de los puntos y su tamaño

# %%
sns.scatterplot(data= tips, x= 'total_bill', y = 'tip', hue= 'day', style= 'time', size='size');
plt.legend(loc= 'center', bbox_to_anchor= (1.12, 0.5));

# %% [markdown]
# Cambiando el formato de los marcadores

# %%
markers = {"Lunch": 'D', "Dinner": 's'}
sns.scatterplot(data= tips, x= 'total_bill', y = 'tip', hue= 'day', style= 'time', size='size', markers = markers);
plt.legend(loc= 'center', bbox_to_anchor= (1.12, 0.5));

# %% [markdown]
# ### Line

# %%
sns.lineplot(data= tips, x= 'total_bill', y = 'tip',  hue= 'day', style= 'time', size='size');

# %% [markdown]
# ### Relplot
#
# Podemos considerarla considerarla como un gráfico general para datos relacionales
#
# Con `kind` podemos modificar el tipo de gráfico

# %%
sns.relplot(data= tips, x= 'total_bill', y = 'tip',  hue= 'day', style= 'time', size='size', kind= 'line');

# %% [markdown]
# Agregar el formato col

# %%
sns.relplot(data= tips, x= 'total_bill', y = 'tip',  hue= 'day', style= 'time', size='size', kind= 'scatter', col = 'time');

# %% [markdown]
# # Jointplot y Pairplot
#
# Nos permiten con un solo comando generar varios tipos de gráficos

# %% [markdown]
# ## Joinplot
#
# Une 2 distintas gráficas en una sola

# %%
sns.jointplot(data=tips, x='total_bill', y= 'tip', hue = 'sex');

# %% [markdown]
# Agregar más argumentos para poder hacer un mejor análisis

# %%
sns.jointplot(data=tips, x='total_bill', y= 'tip', hue='sex', kind= 'hist', marginal_ticks=True, #muestra una pequeña tabla para la gráfica exterior
marginal_kws=dict(bins= 25, fill = True, multiple= 'dodge')); #marginal_kws se le pueden agregar diferentes parámetros

# %% [markdown]
# ## Pairplot
#
# Correlaciona todas las variables numéricas que hay en el dataset

# %%
sns.pairplot(data= tips);

# %% [markdown]
# Solo muestra una esquina del pairplot, eliminando así, las gráficas repetidas

# %%
sns.pairplot(data= tips, corner=True);

# %% [markdown]
# # Heatmap
#
# Heatmap es un tipo de gráfico enfocado a una estructura matricial. Heatmap correlaciona todas las variables numéricas del dataset.

# %% [markdown]
# ## Correlación entre variables
#
# Nos indica cuanta relación hay entre variables

# %%
tips.corr()
# Out:
# C:\Users\wank3\AppData\Local\Temp\ipykernel_13960\3825555837.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tips.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# ## Heatmap
#
# Nos provee de una forma visual de revisar las correlaciones, permitiendo un mejor manejo cuando se tratan grandes cantidades de variables

# %%
sns.heatmap(tips.corr());
# Out:
# C:\Users\wank3\AppData\Local\Temp\ipykernel_13960\1286578210.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tips.corr());

# %% [markdown]
# Se pueden agregar diferentes parámetros. `annot` muestra el valor de la correlación,
# `cmap` color,`linewidthsespacio` entre variables, `linecolor` color de las líneas, `vminv`, `max` valores máximos y mínimos, `cbar=False` eliminar la barra

# %%
sns.heatmap(tips.corr(), annot= True, cmap='coolwarm', linewidths=5, linecolor='black', vmin=0.5,vmax=1,cbar=False);
# Out:
# C:\Users\wank3\AppData\Local\Temp\ipykernel_13960\3171995193.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tips.corr(), annot= True, cmap='coolwarm', linewidths=5, linecolor='black', vmin=0.5,vmax=1,cbar=False);
